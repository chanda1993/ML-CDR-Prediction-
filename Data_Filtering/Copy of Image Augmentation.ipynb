# %%
# !pip install --upgrade albumentations
# Out:
# Requirement already up-to-date: albumentations in /home/chanda/anaconda3/lib/python3.7/site-packages (0.4.6)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /home/chanda/anaconda3/lib/python3.7/site-packages (from albumentations) (4.3.0.36)
# Requirement already satisfied, skipping upgrade: imgaug>=0.4.0 in /home/chanda/anaconda3/lib/python3.7/site-packages (from albumentations) (0.4.0)
# Requirement already satisfied, skipping upgrade: scipy in /home/chanda/anaconda3/lib/python3.7/site-packages (from albumentations) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /home/chanda/anaconda3/lib/python3.7/site-packages (from albumentations) (1.18.1)
# Requirement already satisfied, skipping upgrade: PyYAML in /home/chanda/anaconda3/lib/python3.7/site-packages (from albumentations) (5.3)
# Requirement already satisfied, skipping upgrade: Shapely in /home/chanda/anaconda3/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations) (1.7.0)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/chanda/anaconda3/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations) (3.1.3)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.14.2 in /home/chanda/anaconda3/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations) (0.16.2)
# Requirement already satisfied, skipping upgrade: imageio in /home/chanda/anaconda3/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations) (2.6.1)
# Requirement already satisfied, skipping upgrade: six in /home/chanda/anaconda3/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations) (1.14.0)
# Requirement already satisfied, skipping upgrade: Pillow in /home/chanda/anaconda3/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations) (7.0.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /home/chanda/anaconda3/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations) (2.4.6)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/chanda/anaconda3/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/chanda/anaconda3/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/chanda/anaconda3/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations) (1.1.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /home/chanda/anaconda3/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /home/chanda/anaconda3/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations) (2.4)
# Requirement already satisfied, skipping upgrade: setuptools in /home/chanda/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->imgaug>=0.4.0->albumentations) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /home/chanda/anaconda3/lib/python3.7/site-packages (from networkx>=2.0->scikit-image>=0.14.2->imgaug>=0.4.0->albumentations) (4.4.1)

# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
from pylab import rcParams
from tqdm import tqdm
import matplotlib.pyplot as plt
from matplotlib import rc
import albumentations as A
from pandas.plotting import register_matplotlib_converters
import random

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.2)

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]

sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

rcParams['figure.figsize'] = 12, 8

RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %%
doc_aug = A.Compose([
    A.Flip(p=0.25),
    A.RandomGamma(gamma_limit=(20, 300), p=0.5),
    A.RandomBrightnessContrast(p=0.85),
    A.Rotate(limit=35, p=0.9),
    A.RandomRotate90(p=0.25),
    A.RGBShift(p=0.75),
    A.GaussNoise(p=0.25)
])

# %%
BOX_COLOR = (0, 0, 255)

def visualize_bbox(img, bbox, color=BOX_COLOR, thickness=1):
    x_min, y_min, x_max, y_max = map(lambda v: int(v), bbox)
    
    cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color=color, thickness=thickness)
    return img

# %%
def show_image(image, bbox):
  image = visualize_bbox(image.copy(), bbox)
  f = plt.figure(figsize=(12, 12))
  plt.imshow(
    cv2.cvtColor(image, cv2.COLOR_BGR2RGB),
    interpolation='nearest'
  )
  plt.axis('off')
  f.tight_layout()
  plt.show()

# %%
form = cv2.imread("TEST/img1.png")
CROPPED_BBOX = [0.5, 0.20, 199, 198]

# %%
show_image(form, bbox=CROPPED_BBOX)

# %%
def show_augmented(augmentation, image, bbox):
  augmented = augmentation(image=image, bboxes=[bbox], field_id=['1'])
  show_image(augmented['image'], augmented['bboxes'][0])

# %%
bbox_params = A.BboxParams(
  format='pascal_voc', 
  min_area=1, 
  min_visibility=0.5, 
  label_fields=['field_id']
)

# %%
doc_aug = A.Compose([
    A.Flip(p=0.25),
    A.RandomGamma(gamma_limit=(20, 300), p=0.5),
    A.RandomBrightnessContrast(p=0.85),
    A.Rotate(limit=35, p=0.9),
    A.RandomRotate90(p=0.25),
    A.RGBShift(p=0.75),
    A.GaussNoise(p=0.25)
], bbox_params=bbox_params)

# %%
DATASET_PATH = 'MNIST/MMSE TYPES/Class 1'
IMAGES_PATH = f'{DATASET_PATH}'

os.makedirs(DATASET_PATH, exist_ok=True)
os.makedirs(IMAGES_PATH, exist_ok=True)

rows = []
for i in tqdm(range(100)):
  augmented = doc_aug(image=form, bboxes=[CROPPED_BBOX], field_id=['1'])
  file_name = f'img1{i}.jpg'
    
    
  cv2.imwrite(f'{IMAGES_PATH}/{file_name}', augmented['image'])
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 205.92it/s]

# %%
IMG_DIR = 'data/augmented/images'

for img in os.listdir(IMG_DIR):
        img_array = cv2.imread(os.path.join(IMG_DIR,img), cv2.IMREAD_GRAYSCALE)

        img_array = (img_array.flatten())

        img_array  = img_array.reshape(-1, 1).T

        with open('img1.csv', 'ab') as f:

            np.savetxt(f, img_array, delimiter=",")
